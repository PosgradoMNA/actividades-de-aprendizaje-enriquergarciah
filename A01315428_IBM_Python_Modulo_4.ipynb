# %%
#Learning objets
#Reading file with Open

#File1 = open("file path")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Apuntes
#Lectura de archivo "with Open"
#Glosario de palabras clave:

#open => Abrir
#read mode = r => Leer
#readLine => Leer linea
#readLines => Leer lineas
#close => cerrar
#with => Con
#write mode = w => Escribir
#appending mode = a => Añadir (al final)


#Sintaxis:
#open("nombre del archivo que quieres abrir", "modo de apertura")
#Ejemplo: open("lista_compras.txt", mode="r")
#Lee el archivo lista de compras, dicho archivo es txt

# %%
import pandas as banana
df=banana.DataFrame({'a':[11,21,31],'b':[21,22,23]})
df.head()
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %%
import pandas as pd
df=pd.DataFrame({'a':[1,2,1],'b':[1,1,1]})

# %%
df['a']==1
# Out:
# 0     True
# 1    False
# 2     True
# Name: a, dtype: bool

# %%
df.head()
# Out:
#    a  b
# 0  1  1
# 1  2  1
# 2  1  1
